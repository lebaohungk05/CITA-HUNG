# %% [markdown]
# <a href="https://colab.research.google.com/github/lebaohungk05/CITA-HUNG/blob/master/%5BDA%5D_Week3_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Pandas (Practice)**
#
#
# ---
#
# Lecturer: **Nguyen Van Thieu**

# %%
# !pip install pandas

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.0.3

# %%
s1 = pd.Series([1, 2, 3.0])
print(s1)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# dtype: float64

# %%
s2 = pd.Series([-2.3, "hello", 'banana', 2], index=[1, 2, 3, 4])
print(s2)
# Out:
# 1      -2.3
# 2     hello
# 3    banana
# 4         2
# dtype: object

# %%
s = pd.Series((-0.3, 0.5, 1), index=["b", "a", "c", "d"])
print(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-d437b27108a0> in <cell line: 1>()
# ----> 1 s = pd.Series((-0.3, 0.5, 1), index=["b", "a", "c", "d"])
#       2 print(s)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     498             index = default_index(len(data))
#     499         elif is_list_like(data):
# --> 500             com.require_length_match(data, index)
#     501
#     502         # create/copy the manager
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     574     """
#     575     if len(data) != len(index):
# --> 576         raise ValueError(
#     577             "Length of values "
#     578             f"({len(data)}) "
#
# ValueError: Length of values (3) does not match length of index (4)

# %%
s3 = pd.Series(0.3, index=["a", "b", "c", "d"])
print(s3)
# Out:
# a    0.3
# b    0.3
# c    0.3
# d    0.3
# dtype: float64

# %%
md = {
    "key1": 0.3,
    "key2": "wow",
    "key3": -0.2
}
s4 = pd.Series(md)
print(s4)
# Out:
# key1    0.3
# key2    wow
# key3   -0.2
# dtype: object

# %%
s = pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
#retrieve the first three element
print(s[:3])
#retrieve the last three element
print(s[-3:])
# Out:
# a    1
# b    2
# c    3
# dtype: int64
# c    3
# d    4
# e    5
# dtype: int64

# %%
print(s['a'])
# Out:
# 1

# %%
print(s[['a','c','d']])
# Out:
# a    1
# c    3
# d    4
# dtype: int64

# %%
print(s['f'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'f'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# # DataFrame

# %%
df1 = pd.DataFrame()
print(df1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data = [101, 22, 333, 442, 554]
df2 = pd.DataFrame(data)
print(df2)
# Out:
#      0
# 0  101
# 1   22
# 2  333
# 3  442
# 4  554

# %%
data = (['Alex',10], ['Bob',12], ['Clarke',13])
df3 = pd.DataFrame(data, columns=['Name','Age'])
print(df3)
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13

# %%
data = [['Alex',10],['Bob',12],['Clarke',13]]
df4 = pd.DataFrame(data, columns=['Name','Age'])
print(df4)
print(df4.dtypes)
# Out:
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Clarke   13
# Name    object
# Age      int64
# dtype: object

# %%
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],
        'Age':[28,34,29,42]}
df5 = pd.DataFrame(data)
print(df5)
# Out:
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42

# %%
data = {'Name':['Tom', 'Jack', 'Steve', 'Ricky'],
        'Age':[28, 34, 29, 42]}
df6 = pd.DataFrame(data, index=['rank1','rank2','rank3','rank4'])
print(df6)
# Out:
#         Name  Age
# rank1    Tom   28
# rank2   Jack   34
# rank3  Steve   29
# rank4  Ricky   42

# %%
data = [{'a': 1, 'b': 2},
        {'a': 5, 'b': 10, 'c': 20}]
df7 = pd.DataFrame(data, index=["first", "second"])
print(df7)
# Out:
#         a   b     c
# first   1   2   NaN
# second  5  10  20.0

# %%
data = [{'a': 1, 'b': 2},{'a': 5, 'b': 10, 'c': 20}]

df8 = pd.DataFrame(data, index=['first', 'second'], columns=['b', 'a'])
print(df8)

df9 = pd.DataFrame(data, index=['first', 'second'], columns=['a', 'c', 'b1'])
print(df9)
# Out:
#          b  a
# first    2  1
# second  10  5
#         a     c  b1
# first   1   NaN NaN
# second  5  20.0 NaN

# %%
data = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}
df10 =  pd.DataFrame(data)
print(df10)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %% [markdown]
# ## Các thuộc tính trong Dataframe object
#
# ![image.png](data:image/png;base64,...)

# %%
#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack']),
   'Age':pd.Series([25,26,25,23,30,29,23]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8])}

df = pd.DataFrame(d)
print(df)
# Out:
#     Name  Age  Rating
# 0    Tom   25    4.23
# 1  James   26    3.24
# 2  Ricky   25    3.98
# 3    Vin   23    2.56
# 4  Steve   30    3.20
# 5  Smith   29    4.60
# 6   Jack   23    3.80

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Age     7 non-null      int64
#  2   Rating  7 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 296.0+ bytes

# %%
df.describe()
# Out:
#              Age    Rating
# count   7.000000  7.000000
# mean   25.857143  3.658571
# std     2.734262  0.698628
# min    23.000000  2.560000
# 25%    24.000000  3.220000
# 50%    25.000000  3.800000
# 75%    27.500000  4.105000
# max    30.000000  4.600000

# %%
## Chuyển vị
print(df.T)
# Out:
#            0      1      2     3      4      5     6
# Name     Tom  James  Ricky   Vin  Steve  Smith  Jack
# Age       25     26     25    23     30     29    23
# Rating  4.23   3.24   3.98  2.56    3.2    4.6   3.8

# %%
## Trả lại nhãn của hàng và cột
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=7, step=1), Index(['Name', 'Age', 'Rating'], dtype='object')]

# %%
## Trả lại kiểu của mỗi hàng
print(df.dtypes)
# Out:
# Name       object
# Age         int64
# Rating    float64
# dtype: object

# %%
## Trả lại True nếu dataframe rỗng và ngược lại
print(df.empty)
# Out:
# False

# %%
## Trả lại số chiều của object
print(df.ndim)
# Out:
# 2

# %%
## Trả lại shape của object
print(df.shape)
# Out:
# (7, 3)

# %%
## Trả lại tổng số phần tử
print(df.size)
# Out:
# 21

# %%
## Trả lại data thực tế dưới dạng numpy array (sẽ không còn index hay column name)
print(df.values)
print(type(df.values))
# Out:
# [['Tom' 25 4.23]
#  ['James' 26 3.24]
#  ['Ricky' 25 3.98]
#  ['Vin' 23 2.56]
#  ['Steve' 30 3.2]
#  ['Smith' 29 4.6]
#  ['Jack' 23 3.8]]
# <class 'numpy.ndarray'>

# %%
## Trả lại n phần tử đầu tiên hoặc n phần tử cuối cùng (mặc định n = 5)
print(df.head(10))
# Out:
#     Name  Age  Rating
# 0    Tom   25    4.23
# 1  James   26    3.24
# 2  Ricky   25    3.98
# 3    Vin   23    2.56
# 4  Steve   30    3.20
# 5  Smith   29    4.60
# 6   Jack   23    3.80

# %%
print(df.head(8))
# Out:
#     Name  Age  Rating
# 0    Tom   25    4.23
# 1  James   26    3.24
# 2  Ricky   25    3.98
# 3    Vin   23    2.56
# 4  Steve   30    3.20
# 5  Smith   29    4.60
# 6   Jack   23    3.80

# %%
print(df.tail(9))
# Out:
#     Name  Age  Rating
# 0    Tom   25    4.23
# 1  James   26    3.24
# 2  Ricky   25    3.98
# 3    Vin   23    2.56
# 4  Steve   30    3.20
# 5  Smith   29    4.60
# 6   Jack   23    3.80

# %%
print(df.tail(2))
# Out:
#     Name  Age  Rating
# 5  Smith   29     4.6
# 6   Jack   23     3.8

# %% [markdown]
# ## Selection, Addition, Delete theo cột

# %%
d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)
print(df)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, a to d
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     3 non-null      float64
#  1   two     4 non-null      int64
# dtypes: float64(1), int64(1)
# memory usage: 96.0+ bytes

# %%
print(df["one"])
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %%
print(df["third"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'third'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
## Trả về Series hay DataFrame
print(type(df["one"]))

print(type(df[["one"]]))

print(df["one"])

print(df[["one"]])

print(df[["two", "one"]])
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64
#    one
# a  1.0
# b  2.0
# c  3.0
# d  NaN
#    two  one
# a    1  1.0
# b    2  2.0
# c    3  3.0
# d    4  NaN

# %%
print(df)
df['three'] = pd.Series([10,20,30,40, 40], index=['a','b','c', 'e', 'f'])
print(df)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4
#    one  two  three
# a  1.0    1   10.0
# b  2.0    2   20.0
# c  3.0    3   30.0
# d  NaN    4    NaN

# %%
df["four"] = df['one'] + df['three']
print(df)
# Out:
#    one  two  three  four
# a  1.0    1   10.0  11.0
# b  2.0    2   20.0  22.0
# c  3.0    3   30.0  33.0
# d  NaN    4    NaN   NaN

# %%
## Dùng hàm del để xóa cột
del df['one']
print(df)
# Out:
#    two  three  four
# a    1   10.0  11.0
# b    2   20.0  22.0
# c    3   30.0  33.0
# d    4    NaN   NaN

# %%
## Dùng hàm pop để xóa
out = df.pop("four")
print(out)
print(df)
# Out:
# a    11.0
# b    22.0
# c    33.0
# d     NaN
# Name: four, dtype: float64
#    two  three
# a    1   10.0
# b    2   20.0
# c    3   30.0
# d    4    NaN

# %% [markdown]
# ## Selection, Addition, Deletion theo hàng

# %%
## Sử dụng label trong hàm loc (viết tắt của locate)

d = {'one' : pd.Series([1, 2, 3], index=['a', 'b', 'c']),
   'two' : pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])}
df = pd.DataFrame(d)
print(df)
# Out:
#    one  two
# a  1.0    1
# b  2.0    2
# c  3.0    3
# d  NaN    4

# %%
df[["one", "two"]].values
# Out:
# array([[ 1.,  1.],
#        [ 2.,  2.],
#        [ 3.,  3.],
#        [nan,  4.]])

# %%
df.iloc[2, :]
# Out:
# one    3.0
# two    3.0
# Name: c, dtype: float64

# %%
#df["one"]
df.loc["a"]
# Out:
# one    1.0
# two    1.0
# Name: a, dtype: float64

# %%
df.loc["c"]
# Out:
# one    3.0
# two    3.0
# Name: c, dtype: float64

# %%
## Sử dụng integer location trong hàm iloc (viết tắt của integer locate)

df.iloc[1, 0]
# Out:
# 2.0

# %%
d = {'one' : pd.Series([1, 2, 3], index=[0, 1, 2]),
   'two' : pd.Series([1, 2, 3, 4], index=[0, 1, 2, 4])}
df = pd.DataFrame(d)
print(df)

print(df.loc[1])
# Out:
#    one  two
# 0  1.0    1
# 1  2.0    2
# 2  3.0    3
# 4  NaN    4
# one    2.0
# two    2.0
# Name: 1, dtype: float64

# %%
## Chia cắt theo hàng có thể dùng như numpy (Không chia cắt theo cột được)

print(df[1:2])
print(df[-2:])
# Out:
#    one  two
# 1  2.0    2
#    one  two
# 2  3.0    3
# 4  NaN    4

# %%
print(df[1:2, 1:2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(1, 2, None), slice(1, 2, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-51-aff9cf5c3b55> in <cell line: 1>()
# ----> 1 print(df[1:2, 1:2])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
# ...

# %%
print(df)
# Out:
#    one  two
# 0  1.0    1
# 1  2.0    2
# 2  3.0    3
# 4  NaN    4

# %%
print(df.loc[1:2, "one":"two"])
# Out:
#    one  two
# 1  2.0    2
# 2  3.0    3

# %%
## Muốn cắt cả hàng cả cột như numpy, thì phải truyền chỉ số vào hàm iloc
print(df.iloc[0:2, 1:2])
# Out:
#    two
# 0    1
# 1    2

# %%
## Dùng hàm append để thêm hàng

df = pd.DataFrame([[1, 2], [3, 4]], columns = ['a','b'])
df2 = pd.DataFrame([[5, 6], [7, 8]], columns = ['a','b'])

df = df.append(df2)
print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-348368f0e012> in <cell line: 6>()
#       4 df2 = pd.DataFrame([[5, 6], [7, 8]], columns = ['a','b'])
#       5
# ----> 6 df = df.append(df2)
#       7 print(df)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
## Dùng nhãn index để xóa hàng, nếu nhiều nhãn bị trùng thì nhiều hàng bị xóa.

# Xóa hàng với nhãn index = 1
df = df.drop(1)
print(df)
# Out:
#    a  b
# 0  1  2
# 0  5  6

# %% [markdown]
# # Indexing and Selecting data

# %% [markdown]
# ## .loc()
# - Lập chỉ mục dựa hoàn toàn trên label. Integer cũng là label hợp lệ nhưng nó tham chiếu đến label chứ không phải vị trí.

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.randn(8, 4),
                  index = ['a','b','c','d','e','f','g','h'],
                  columns = ['A', 'B', 'C', 'D'])

print(df)
# Out:
#           A         B         C         D
# a  1.059339  0.767140  0.895909 -0.557704
# b  2.031888 -0.126295  0.913298  1.738048
# c  0.835867 -1.681265  0.432287  1.138770
# d  0.727614  0.450426  0.158582  0.064013
# e  0.545709 -0.635812  0.204832  0.728666
# f  0.722129  0.867516 -0.881583 -0.049137
# g -0.290864  0.475757 -0.931269 -1.177738
# h  0.035780  0.606738 -1.620067 -0.230587

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(np.arange(32).reshape(8, 4),
                  index = ['a','b','c','d','e','f','g','h'],
                  columns = ['D', 'B', 'A', 'C'])

print(df)
print(df.loc[:, 'A'])
# Out:
#     D   B   A   C
# a   0   1   2   3
# b   4   5   6   7
# c   8   9  10  11
# d  12  13  14  15
# e  16  17  18  19
# f  20  21  22  23
# g  24  25  26  27
# h  28  29  30  31
# a     2
# b     6
# c    10
# d    14
# e    18
# f    22
# g    26
# h    30
# Name: A, dtype: int64

# %%
print(df.loc[:, 'B'])
# Out:
# a     1
# b     5
# c     9
# d    13
# e    17
# f    21
# g    25
# h    29
# Name: B, dtype: int64

# %%
print(df.loc[:, 'B':'D'])
# Out:
# Empty DataFrame
# Columns: []
# Index: [a, b, c, d, e, f, g, h]

# %%
print(df.loc[:, 'D':'A'])
# Out:
#     D   B   A
# a   0   1   2
# b   4   5   6
# c   8   9  10
# d  12  13  14
# e  16  17  18
# f  20  21  22
# g  24  25  26
# h  28  29  30

# %%
print(df.loc['a'])
# Out:
# A   -1.239354
# B    0.726570
# C   -1.142945
# D   -0.088747
# Name: a, dtype: float64

# %%
print(df.loc["A"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'A'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print(df.loc[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print(df.loc['c':'f', 'B':'D'])
# Out:
#           B         C         D
# c -1.689485  0.599146 -0.946763
# d  0.482910  0.563778  0.829237
# e  0.292757  0.186043  0.448718
# f -1.729186 -0.115908 -0.857603

# %%
print(df.loc['f':'c', 'B':'D'])
# Out:
# Empty DataFrame
# Columns: [B, C, D]
# Index: []

# %%
print(df.loc['a':'d', ('B','D')])
# Out:
#           B         D
# a  0.726570 -0.088747
# b  0.393656  0.044823
# c -1.689485 -0.946763
# d  0.482910  0.829237

# %%
print(df.loc[['a', 'd'], ['A','D']])
# Out:
#           A         D
# a -1.239354 -0.088747
# d -1.961525  0.829237

# %%
print(df)


print(df.loc[:, 'A'] > 0)
print(df[df.loc[:, 'A'] > 0]['A'])
# Out:
#     A   B   C   D
# a   0   1   2   3
# b   4   5   6   7
# c   8   9  10  11
# d  12  13  14  15
# e  16  17  18  19
# f  20  21  22  23
# g  24  25  26  27
# h  28  29  30  31
# a    False
# b     True
# c     True
# d     True
# e     True
# f     True
# g     True
# h     True
# Name: A, dtype: bool
# b     4
# c     8
# d    12
# e    16
# f    20
# g    24
# h    28
# Name: A, dtype: int64

# %% [markdown]
# ## .iloc()
#
# Lấy giá trị dựa vào chỉ số vị trí (position). Tương tự như python, numpy sẽ đếm từ 0

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns = ['A', 'B', 'C', 'D'])
print(df)
# Out:
#           A         B         C         D
# 0  0.099496 -0.362038 -0.709441 -0.362075
# 1 -2.621637 -0.711981 -2.630626  0.077078
# 2  0.560040 -0.651897  0.025330 -0.274602
# 3 -0.675268 -0.569106 -0.563214  0.991662
# 4  0.094337  0.516621 -1.263693  0.049689
# 5  0.618319 -0.005457  0.761359  0.656207
# 6  0.760868  0.013343 -1.072147 -0.608992
# 7 -1.258988  0.837022  0.310735 -0.747252

# %%
print(df.iloc[:,:4])
# Out:
#           A         B         C         D
# 0  0.099496 -0.362038 -0.709441 -0.362075
# 1 -2.621637 -0.711981 -2.630626  0.077078
# 2  0.560040 -0.651897  0.025330 -0.274602
# 3 -0.675268 -0.569106 -0.563214  0.991662
# 4  0.094337  0.516621 -1.263693  0.049689
# 5  0.618319 -0.005457  0.761359  0.656207
# 6  0.760868  0.013343 -1.072147 -0.608992
# 7 -1.258988  0.837022  0.310735 -0.747252

# %%
print(df.iloc[:3, [1, 2]])
# Out:
#           B         C
# 0 -0.362038 -0.709441
# 1 -0.711981 -2.630626
# 2 -0.651897  0.025330

# %%
print(df.iloc[[1, 2], [3, 1]])
# Out:
#           D         B
# 1  0.077078 -0.711981
# 2 -0.274602 -0.651897

# %%
print(df.iloc[0:2, -3:2])
# Out:
#           B
# 0 -0.362038
# 1 -0.711981

# %% [markdown]
# ## Boolean indexing
#
# Lấy dữ liệu dựa vào giá trị thực tế trong DataFrame chứ không phải dựa vào label của hàng hay cột. Lọc theo 4 cách dưới đây:
#
# + Truy cập DataFrame với boolean index
# + Truy cập DataFrame với boolean mask (tương tự như numpy)
# + Masking dữ liệu dựa vào giá trị ở cột
# + Masking dữ liệu dựa vào giá trị index

# %% [markdown]
# ### Truy cập DataFrame với boolean index
#
# - Cần tạo DataFrame với index là True hoặc False

# %%
data = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}

df = pd.DataFrame(data, index = [True, False, True, False])
print(df)
print(df.loc[True])
print("\n")
print(df.iloc[int(True)])
# Out:
#          name  degree  score
# True   aparna     MBA     90
# False  pankaj     BCA     40
# True   sudhir  M.Tech     80
# False   Geeku     MBA     98
#         name  degree  score
# True  aparna     MBA     90
# True  sudhir  M.Tech     80
#
#
# name      pankaj
# degree       BCA
# score         40
# Name: False, dtype: object

# %% [markdown]
# ### Truy cập DataFrame với boolean mask

# %%
print(df)
df[[True, True, True, False]]
# Out:
#          name  degree  score
# True   aparna     MBA     90
# False  pankaj     BCA     40
# True   sudhir  M.Tech     80
# False   Geeku     MBA     98
#          name  degree  score
# True   aparna     MBA     90
# False  pankaj     BCA     40
# True   sudhir  M.Tech     80

# %% [markdown]
# ### Masking dữ liệu dựa vào giá trị ở cột
# Sử dụng các toán tử thông thường như: ==, >, <, <=, >= để tạo bộ lọc (filter).
# Nó sẽ trả về Series của giá trị True hoặc False

# %%
import numpy as np

data = np.random.uniform(0, 3, (7, 4))
df = pd.DataFrame(data, index = list(range(0, 7)), columns=list('abcd'))
df
# Out:
#           a         b         c         d
# 0  0.941161  2.707707  2.200501  2.081389
# 1  0.770016  2.170334  1.041382  0.897709
# 2  2.569591  2.765521  2.599889  2.627615
# 3  1.575968  0.712158  1.391767  1.782896
# 4  0.600847  0.462279  1.591386  1.078640
# 5  1.973524  1.063698  1.951985  0.539007
# 6  0.217681  0.054939  2.599007  0.440825

# %%
df['a'] > 1
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# Name: a, dtype: bool

# %%
df[df['a'] > 1]
# Out:
#           a         b         c         d
# 0  1.872101  2.352494  0.998783  2.467733
# 3  2.747035  2.760471  0.105345  1.932076
# 4  1.363932  1.204998  2.912501  2.768396
# 5  2.171793  2.887654  2.620034  1.328465
# 6  1.170927  2.431383  1.620133  1.349111

# %% [markdown]
# ### Masking dữ liệu dựa vào giá trị index
#
# Index nên là các giá trị số nguyên để dễ dàng thực hiện các phép so sánh tạo bộ lọc

# %%
data = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["BCA", "BCA", "M.Tech", "BCA"],
        'score':[90, 40, 80, 98]}

df = pd.DataFrame(data, index = [0, 1, 2, 3])
print(df)

mask = df.index == 2
print(mask)
print(df[mask])
# Out:
#      name  degree  score
# 0  aparna     BCA     90
# 1  pankaj     BCA     40
# 2  sudhir  M.Tech     80
# 3   Geeku     BCA     98
# [False False  True False]
#      name  degree  score
# 2  sudhir  M.Tech     80

# %% [markdown]
# # Lập lại chỉ mục (Reindexing)
#
# Thay đổi labels của hàng hoặc cột. Các phép toán có thể:
#
# + Thay đổi thứ tự của dữ liệu để phù hợp với label mới
# + Thêm giá trị còn thiếu vào vị trí của label

# %%
import numpy as np

N=20

df = pd.DataFrame({
   'A': pd.date_range(start='2016-01-01', periods=N, freq='D'),
   'x': np.linspace(0,stop=N-1,num=N),
   'y': np.random.rand(N),
   'C': np.random.choice(['Low','Medium','High'], N).tolist(),
   'D': np.random.normal(100, 10, size=(N)).tolist()
})
print(df)
# Out:
#             A     x         y       C           D
# 0  2016-01-01   0.0  0.465052  Medium  101.780881
# 1  2016-01-02   1.0  0.198831     Low   72.528158
# 2  2016-01-03   2.0  0.687135    High  108.467940
# 3  2016-01-04   3.0  0.074301  Medium  103.773403
# 4  2016-01-05   4.0  0.791112     Low  101.296341
# 5  2016-01-06   5.0  0.837142    High  108.191085
# 6  2016-01-07   6.0  0.027848     Low  107.121261
# 7  2016-01-08   7.0  0.582306  Medium  103.337539
# 8  2016-01-09   8.0  0.262009  Medium  115.091791
# 9  2016-01-10   9.0  0.261031  Medium   98.796848
# 10 2016-01-11  10.0  0.024312  Medium  100.757453
# 11 2016-01-12  11.0  0.522964     Low   95.031588
# 12 2016-01-13  12.0  0.576369  Medium   86.862036
# 13 2016-01-14  13.0  0.290303     Low   99.036602
# 14 2016-01-15  14.0  0.772164  Medium   83.598499
# 15 2016-01-16  15.0  0.338449  Medium  105.059542
# 16 2016-01-17  16.0  0.041369  Medium   92.376553
# 17 2016-01-18  17.0  0.067878    High  111.989096
# ...

# %%
#reindex the DataFrame
df_reindexed = df.reindex(index=[0, 2, 5], columns=['A', 'C', 'B'])
print(df_reindexed)
# Out:
#            A       C   B
# 0 2016-01-01  Medium NaN
# 2 2016-01-03    High NaN
# 5 2016-01-06    High NaN

# %%
df1 = pd.DataFrame(np.random.randn(10,3),columns=['col1','col2','col3'])
df2 = pd.DataFrame(np.random.randn(7,4),columns=['col1','col2','col3', 'col4'])
print(df1)
print(df2)
# Out:
#        col1      col2      col3
# 0  1.187990 -0.282191  0.300088
# 1  0.406402 -1.550021 -2.208355
# 2 -0.091963 -1.859596 -0.669529
# 3 -1.160172 -1.302026 -1.120159
# 4  1.646288  1.068548 -2.446569
# 5  1.861021  1.154822  0.390971
# 6  0.166186  1.097492 -1.102043
# 7 -0.786307 -0.396022  0.615975
# 8  0.314920  1.216902 -0.524838
# 9 -2.551329  0.026010  0.812453
#        col1      col2      col3      col4
# 0  0.508659 -0.144630 -0.397932 -0.024322
# 1  1.031251 -0.218925  0.397895 -0.552875
# 2  1.328284 -0.680019  1.159733  0.751011
# 3 -0.659561  0.899006 -1.374880  0.096969
# 4  0.409473 -0.588957  1.754833  1.343564
# 5  1.511586  0.335752  0.547280 -1.105480
# 6  0.441119 -0.436143 -1.455283 -1.776077

# %%
df1 = df1.reindex_like(df2)
print(df1)
# Out:
#        col1      col2      col3  col4
# 0 -1.290924 -2.197990 -0.960447   NaN
# 1 -0.742529  0.792593  0.247644   NaN
# 2  0.076105 -0.240033  0.356910   NaN
# 3 -0.239996 -0.360287  1.270783   NaN
# 4  0.472950 -0.060296  0.237982   NaN
# 5 -0.395770  1.173757 -0.359438   NaN
# 6 -1.908862 -0.319582  0.479913   NaN

# %%
df1.set_index(df2.index)

# %% [markdown]
# ## Filling while reindexing
# Hàm reindex() có tham số filling với các giá trị sau:
#
# + pad/ffill: Điền các giá trị tiếp theo
# + bfill/backfill: Điền các giá trị trước đó
# + nearest: Điền các giá trị gần index nhất

# %%
df1 = pd.DataFrame(np.random.randn(6,3),columns=['col1','col2','col3'])
df2 = pd.DataFrame(np.random.randn(2,3),columns=['col1','col2','col3'])
print(df1)
print(df2)
# Out:
#        col1      col2      col3
# 0  0.237739 -0.019872 -0.814462
# 1 -1.110582 -0.518995  0.832312
# 2  1.431157  0.077336  0.248768
# 3  1.426954 -0.604389  0.527181
# 4 -0.720273  0.355374  0.303668
# 5 -0.172704 -0.019864 -0.843915
#        col1      col2      col3
# 0 -0.425946  0.265179 -1.346571
# 1  0.117443 -0.374768 -0.641172

# %%
# Padding NAN's
print(df2.reindex_like(df1))
# Out:
#        col1      col2      col3
# 0 -0.425946  0.265179 -1.346571
# 1  0.117443 -0.374768 -0.641172
# 2       NaN       NaN       NaN
# 3       NaN       NaN       NaN
# 4       NaN       NaN       NaN
# 5       NaN       NaN       NaN

# %%
# Now Fill the NAN's with preceding Values
print("Data Frame with Forward Fill:")
print(df2.reindex_like(df1, method='ffill'))
# Out:
# Data Frame with Forward Fill:
#        col1      col2      col3
# 0 -0.425946  0.265179 -1.346571
# 1  0.117443 -0.374768 -0.641172
# 2  0.117443 -0.374768 -0.641172
# 3  0.117443 -0.374768 -0.641172
# 4  0.117443 -0.374768 -0.641172
# 5  0.117443 -0.374768 -0.641172

# %%
print(df2.reindex_like(df1, method='bfill'))
# Out:
#        col1      col2      col3
# 0 -0.425946  0.265179 -1.346571
# 1  0.117443 -0.374768 -0.641172
# 2       NaN       NaN       NaN
# 3       NaN       NaN       NaN
# 4       NaN       NaN       NaN
# 5       NaN       NaN       NaN

# %%
print(df2.reindex_like(df1, method='nearest'))
# Out:
#        col1      col2      col3
# 0 -0.425946  0.265179 -1.346571
# 1  0.117443 -0.374768 -0.641172
# 2  0.117443 -0.374768 -0.641172
# 3  0.117443 -0.374768 -0.641172
# 4  0.117443 -0.374768 -0.641172
# 5  0.117443 -0.374768 -0.641172

# %%
## Thiết lập limit số hàng được fill
print(df2.reindex_like(df1, method='ffill', limit=2))
# Out:
#        col1      col2      col3
# 0  0.879340  0.051497  0.839872
# 1  0.705517  0.847873  0.200052
# 2  0.705517  0.847873  0.200052
# 3  0.705517  0.847873  0.200052
# 4       NaN       NaN       NaN
# 5       NaN       NaN       NaN

# %% [markdown]
# ## fill_value
#
# Hoặc sử dụng tham số fill_value thay vì dùng method để fill

# %%
column =['a', 'b', 'c', 'd', 'e']
index =['A', 'B', 'C', 'D', 'E']
df1 = pd.DataFrame(np.random.rand(5, 5), columns = column, index = index)

column_new =['a', 'b', 'c', 'g', 'h']
print(df1.reindex(column_new, axis ='columns', fill_value ='data missing'))
# Out:
#           a         b         c             g             h
# A  0.030169  0.463300  0.537696  data missing  data missing
# B  0.810076  0.114105  0.985770  data missing  data missing
# C  0.157571  0.158475  0.276363  data missing  data missing
# D  0.526668  0.956845  0.120669  data missing  data missing
# E  0.208763  0.744393  0.889459  data missing  data missing

# %%
print(df1.reindex(columns=column_new, fill_value = 0))
# Out:
#           a         b         c  g  h
# A  0.030169  0.463300  0.537696  0  0
# B  0.810076  0.114105  0.985770  0  0
# C  0.157571  0.158475  0.276363  0  0
# D  0.526668  0.956845  0.120669  0  0
# E  0.208763  0.744393  0.889459  0  0

# %%
df1.reindex?

# %%
index_new =['E', 'D', 'G', 'H']
print(df1.reindex(index=index_new, fill_value = 0))
# Out:
#           a         b         c         d         e
# E  0.042115  0.683723  0.969846  0.283727  0.375943
# D  0.085371  0.546481  0.417223  0.322948  0.457327
# G  0.000000  0.000000  0.000000  0.000000  0.000000
# H  0.000000  0.000000  0.000000  0.000000  0.000000

# %% [markdown]
# ## rename()
# Thay đổi tên của hàng hoặc cột

# %%
df1 = pd.DataFrame(np.random.randn(6,3),columns=['col1','col2','col3'])
print(df1)
# Out:
#        col1      col2      col3
# 0  0.256072 -0.123207 -1.761796
# 1  1.488085  1.187976  0.876223
# 2  0.785418 -0.142865 -0.373098
# 3  1.900373  0.817525  0.811661
# 4  1.145836  1.816425  0.787273
# 5  1.823014 -1.022389 -0.516044

# %%
df2 = df1.rename(columns={'col1' : 'c1', 'col2' : 'c2'},
                 index = {0 : 'apple', 1 : 'banana', 2 : 'durian'})
print(df2)
# Out:
#               c1        c2      col3
# apple   0.256072 -0.123207 -1.761796
# banana  1.488085  1.187976  0.876223
# durian  0.785418 -0.142865 -0.373098
# 3       1.900373  0.817525  0.811661
# 4       1.145836  1.816425  0.787273
# 5       1.823014 -1.022389 -0.516044

# %%
df1.rename(columns={'col1' : 'c1', 'col2' : 'c2'}, index = {0 : 'apple', 1 : 'banana', 2 : 'durian'}, inplace=True)
print(df1)
# Out:
#               c1        c2      col3
# apple   0.238508 -0.418996 -1.903502
# banana  0.250429  1.309215 -0.450121
# durian  0.394700 -0.005006 -0.877488
# 3      -0.932769 -1.990908 -1.695254
# 4       0.322117 -0.394745  0.048749
# 5       2.817304  2.155008  0.509695

# %% [markdown]
# # Sorting
#
# 1.   **Nhãn (label/index)**: tên hàng hoặc tên cột
# 2.   **Giá trị (value)**: giá trị của từng cell
# 3.   **Vị trí (position)**: Vị trí của từng cell
#
#
# 2 hàm chính là **.sort_values** và **.sort_index()**
#
# có thể sort theo hàng hoặc theo cột dựa vào giá trị (values) hoặc nhãn (label)

# %% [markdown]
# - Bộ data về mức tiết kiệm nhiên liệu do Cơ quan Bảo vệ Môi trường Hoa Kỳ (EPA) biên soạn trên các phương tiện được sản xuất từ ​​năm 1984 đến năm 2021.
#
# - Nó có nhiều các loại thông tin khác nhau từ kiểu dữ liệu số đến dữ liệu dạng văn bản mà dựa vào đó người dùng có thể thực hiện việc sắp xếp.
#
# - Tập dữ liệu này có tổng cộng 83 cột.
#
# - Trong ví dụ này ta dùng cột: miles/gallon (MPG) trên xe theo kiểu xe, năm, sản xuất và các thuộc tính khác.
#
# - Data có thể lấy ở link sau: [link text](https://github.com/thieu1995/csv-files/blob/main/data/pandas/vehicles.csv)

# %%
## Load dataset

column_subset = [
     "id",
     "make",
     "model",
     "year",
     "cylinders",
     "fuelType",
     "trany",
     "mpgData",
     "city08",
     "highway08"
 ]

df = pd.read_csv(
    "https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/vehicles.csv",
    usecols = column_subset,
    nrows = 100
)

df.head()
# Out:
#    city08  cylinders fuelType  highway08     id        make  \
# 0      19          4  Regular         25      1  Alfa Romeo
# 1       9         12  Regular         14     10     Ferrari
# 2      23          4  Regular         33    100       Dodge
# 3      10          8  Regular         12   1000       Dodge
# 4      17          4  Premium         23  10000      Subaru
#
#                  model mpgData            trany  year
# 0   Spider Veloce 2000       Y     Manual 5-spd  1985
# 1           Testarossa       N     Manual 5-spd  1985
# 2              Charger       Y     Manual 5-spd  1985
# 3  B150/B250 Wagon 2WD       N  Automatic 3-spd  1985
# 4     Legacy AWD Turbo       N     Manual 5-spd  1993

# %%
df.describe()
# Out:
#            city08   cylinders   highway08            id         year
# count  100.000000  100.000000  100.000000    100.000000   100.000000
# mean    16.790000    5.940000   23.470000   8929.750000  1992.040000
# std      3.373381    1.644212    4.560381   3034.851599     2.612789
# min      9.000000    4.000000   10.000000      1.000000  1985.000000
# 25%     15.000000    4.000000   22.000000  10012.750000  1993.000000
# 50%     17.000000    6.000000   24.000000  10037.500000  1993.000000
# 75%     18.000000    6.000000   26.000000  10062.250000  1993.000000
# max     23.000000   12.000000   33.000000  10087.000000  1993.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city08     100 non-null    int64
#  1   cylinders  100 non-null    int64
#  2   fuelType   100 non-null    object
#  3   highway08  100 non-null    int64
#  4   id         100 non-null    int64
#  5   make       100 non-null    object
#  6   model      100 non-null    object
#  7   mpgData    100 non-null    object
#  8   trany      100 non-null    object
#  9   year       100 non-null    int64
# dtypes: int64(5), object(5)
# memory usage: 7.9+ KB

# %% [markdown]
# ## sort_values()
#
# - có thể sort theo hàng hoặc cột, nhiều hàng hoặc nhiều cột cùng lúc.

# %%
df.sort_values?

# %%
df.sort_values('highway08')
# Out:
#     city08  cylinders fuelType  highway08     id    make                model  \
# 80       9          8  Regular         10   1007   Dodge       B350 Wagon 2WD
# 58      10          8  Regular         11   1005   Dodge       B350 Wagon 2WD
# 47       9          8  Regular         11   1004   Dodge  B150/B250 Wagon 2WD
# 69      10          8  Regular         11   1006   Dodge       B350 Wagon 2WD
# 3       10          8  Regular         12   1000   Dodge  B150/B250 Wagon 2WD
# ..     ...        ...      ...        ...    ...     ...                  ...
# 10      23          4  Regular         30  10006  Toyota              Corolla
# 9       23          4  Regular         30  10005  Toyota              Corolla
# 76      23          4  Regular         31  10066   Mazda                  626
# 8       23          4  Regular         31  10004  Toyota              Corolla
# 2       23          4  Regular         33    100   Dodge              Charger
#
# ...

# %%
df.sort_values(by="year", ascending=False)
# Out:
#     city08  cylinders fuelType  highway08     id        make  \
# 50      18          6  Regular         24  10042       Dodge
# 62      15          6  Premium         22  10053        Ford
# 72      15          8  Regular         22  10062     Mercury
# 71      17          6  Regular         24  10061     Mercury
# 70      16          8  Premium         22  10060       Lexus
# ..     ...        ...      ...        ...    ...         ...
# 69      10          8  Regular         11   1006       Dodge
# 36      11          8  Regular         17   1003       Dodge
# 58      10          8  Regular         11   1005       Dodge
# 1        9         12  Regular         14     10     Ferrari
# 0       19          4  Regular         25      1  Alfa Romeo
#
#                   model mpgData            trany  year
# 50              Dynasty       N  Automatic 4-spd  1993
# 62          Thunderbird       N     Manual 5-spd  1993
# 72               Cougar       Y  Automatic 4-spd  1993
# ...

# %% [markdown]
# - Có thể dùng các loại giải thuật sắp xếp khác nhau như: **heapsort, mergesort, quicksort**
#
# - quicksort là mặc định
# - heapsort chậm nhất và không ổn định

# %%
df.sort_values(by="make", key=lambda col: col.str.lower(), kind="mergesort")
# Out:
#     city08  cylinders fuelType  highway08     id        make  \
# 0       19          4  Regular         25      1  Alfa Romeo
# 18      17          6  Premium         22  10013        Audi
# 19      17          6  Premium         24  10014        Audi
# 20      14          8  Premium         20  10015         BMW
# 21      14          8  Premium         20  10016         BMW
# ..     ...        ...      ...        ...    ...         ...
# 12      21          4  Regular         29  10008  Volkswagen
# 13      18          4  Regular         26  10009  Volkswagen
# 15      20          4  Regular         28  10010  Volkswagen
# 16      18          4  Regular         23  10011       Volvo
# 17      19          4  Regular         26  10012       Volvo
#
#                  model mpgData            trany  year
# 0   Spider Veloce 2000       Y     Manual 5-spd  1985
# 18                 100       Y  Automatic 4-spd  1993
# 19                 100       N     Manual 5-spd  1993
# ...

# %% [markdown]
# ### Sort multiple columns
#
# - Ví dụ ta có data là họ và tên và muốn sort dựa theo tên, sau đó là họ. Vậy những người có trùng tên sẽ được sắp xếp theo thú tự bảng chữ cái dựa vào họ.

# %%
## Ví dụ sort city và miles/gallon

df.sort_values(by=['city08', 'highway08'])[["city08", "highway08"]]
# Out:
#     city08  highway08
# 80       9         10
# 47       9         11
# 99       9         13
# 1        9         14
# 58      10         11
# ..     ...        ...
# 9       23         30
# 10      23         30
# 8       23         31
# 76      23         31
# 2       23         33
#
# [100 rows x 2 columns]

# %%
df.sort_values(by=["model", "make"])[["make", "model"]]
# Out:
#              make        model
# 18           Audi          100
# 19           Audi          100
# 16          Volvo          240
# 17          Volvo          240
# 75          Mazda          626
# ..            ...          ...
# 62           Ford  Thunderbird
# 63           Ford  Thunderbird
# 88     Oldsmobile     Toronado
# 42  CX Automotive        XM v6
# 43  CX Automotive       XM v6a
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Sort multiple columns with different sort orders
#
# - Mỗi cột có thể chọn một thứ tự sort khác nhau.

# %%
df.sort_values(by=["make", "model", "city08"], ascending=[True, True, False])[["make", "model", "city08"]]
# Out:
#           make               model  city08
# 0   Alfa Romeo  Spider Veloce 2000      19
# 18        Audi                 100      17
# 19        Audi                 100      17
# 20         BMW                740i      14
# 21         BMW               740il      14
# ..         ...                 ...     ...
# 11  Volkswagen      Golf III / GTI      18
# 15  Volkswagen           Jetta III      20
# 13  Volkswagen           Jetta III      18
# 17       Volvo                 240      19
# 16       Volvo                 240      18
#
# [100 rows x 3 columns]

# %% [markdown]
# ## sort_index()
#
# - Bến trên ta sort giá trị, tức là tráo đổi các hàng với nhau, do vậy nhãn của các hàng sẽ bị lộn xộn. Ta dùng hàm sort_index() để chỉnh lại nhãn của các hàng.

# %%
sorted_df = df.sort_values(by=["make", "model"])
sorted_df
# Out:
#     city08  cylinders fuelType  highway08     id        make  \
# 0       19          4  Regular         25      1  Alfa Romeo
# 18      17          6  Premium         22  10013        Audi
# 19      17          6  Premium         24  10014        Audi
# 20      14          8  Premium         20  10015         BMW
# 21      14          8  Premium         20  10016         BMW
# ..     ...        ...      ...        ...    ...         ...
# 12      21          4  Regular         29  10008  Volkswagen
# 13      18          4  Regular         26  10009  Volkswagen
# 15      20          4  Regular         28  10010  Volkswagen
# 16      18          4  Regular         23  10011       Volvo
# 17      19          4  Regular         26  10012       Volvo
#
#                  model mpgData            trany  year
# 0   Spider Veloce 2000       Y     Manual 5-spd  1985
# 18                 100       Y  Automatic 4-spd  1993
# 19                 100       N     Manual 5-spd  1993
# ...

# %%
sorted_df.sort_index()
# Out:
#     city08  cylinders fuelType  highway08     id         make  \
# 0       19          4  Regular         25      1   Alfa Romeo
# 1        9         12  Regular         14     10      Ferrari
# 2       23          4  Regular         33    100        Dodge
# 3       10          8  Regular         12   1000        Dodge
# 4       17          4  Premium         23  10000       Subaru
# ..     ...        ...      ...        ...    ...          ...
# 95      17          6  Regular         25  10083      Pontiac
# 96      17          6  Regular         27  10084      Pontiac
# 97      15          6  Regular         24  10085      Pontiac
# 98      15          6  Regular         24  10086      Pontiac
# 99       9          8  Premium         13  10087  Rolls-Royce
#
#                    model mpgData            trany  year
# 0     Spider Veloce 2000       Y     Manual 5-spd  1985
# 1             Testarossa       N     Manual 5-spd  1985
# ...

# %% [markdown]
# - Ta có thể thay thế nhãn của hàng dựa trên số nguyên mặc định bằng hai cột nhãn. Đây được coi là chỉ số phân cấp (hierarchical Index hoặc MultipleIndex).
#
# - DataFrame hiện được lập chỉ mục bởi nhiều hơn một khóa, có thể được sắp xếp bằng cách sử dụng .sort_index().

# %%
df_2 = df.set_index(["make", "model"])
df_2
# Out:
#                                   city08  cylinders fuelType  highway08  \
# make        model
# Alfa Romeo  Spider Veloce 2000        19          4  Regular         25
# Ferrari     Testarossa                 9         12  Regular         14
# Dodge       Charger                   23          4  Regular         33
#             B150/B250 Wagon 2WD       10          8  Regular         12
# Subaru      Legacy AWD Turbo          17          4  Premium         23
# ...                                  ...        ...      ...        ...
# Pontiac     Grand Prix                17          6  Regular         25
#             Grand Prix                17          6  Regular         27
#             Grand Prix                15          6  Regular         24
#             Grand Prix                15          6  Regular         24
# Rolls-Royce Brooklands/Brklnds L       9          8  Premium         13
#
#                                      id mpgData            trany  year
# ...

# %%
df_2.sort_index()
# Out:
#                                city08  cylinders fuelType  highway08     id  \
# make       model
# Alfa Romeo Spider Veloce 2000      19          4  Regular         25      1
# Audi       100                     17          6  Premium         22  10013
#            100                     17          6  Premium         24  10014
# BMW        740i                    14          8  Premium         20  10015
#            740il                   14          8  Premium         20  10016
# ...                               ...        ...      ...        ...    ...
# Volkswagen Golf III / GTI          21          4  Regular         29  10008
#            Jetta III               18          4  Regular         26  10009
#            Jetta III               20          4  Regular         28  10010
# Volvo      240                     18          4  Regular         23  10011
#            240                     19          4  Regular         26  10012
#
# ...

# %%
df_2.sort_index?

# %%
df_2.sort_index(ascending=False)
# Out:
#                                city08  cylinders fuelType  highway08     id  \
# make       model
# Volvo      240                     18          4  Regular         23  10011
#            240                     19          4  Regular         26  10012
# Volkswagen Jetta III               18          4  Regular         26  10009
#            Jetta III               20          4  Regular         28  10010
#            Golf III / GTI          18          4  Regular         26  10007
# ...                               ...        ...      ...        ...    ...
# BMW        740il                   14          8  Premium         20  10016
#            740i                    14          8  Premium         20  10015
# Audi       100                     17          6  Premium         22  10013
#            100                     17          6  Premium         24  10014
# Alfa Romeo Spider Veloce 2000      19          4  Regular         25      1
#
# ...

# %% [markdown]
# ### Sort column labels
#
# - Sử dụng tham số axis=1 để sort nhãn của cột
#
# - Rất hữu ích nếu data có nhãn cột là tháng/năm. Sắp xếp data theo thứ tự bởi tháng sẽ hợp lí.

# %%
df.sort_index(axis=1)
# Out:
#     city08  cylinders fuelType  highway08     id         make  \
# 0       19          4  Regular         25      1   Alfa Romeo
# 1        9         12  Regular         14     10      Ferrari
# 2       23          4  Regular         33    100        Dodge
# 3       10          8  Regular         12   1000        Dodge
# 4       17          4  Premium         23  10000       Subaru
# ..     ...        ...      ...        ...    ...          ...
# 95      17          6  Regular         25  10083      Pontiac
# 96      17          6  Regular         27  10084      Pontiac
# 97      15          6  Regular         24  10085      Pontiac
# 98      15          6  Regular         24  10086      Pontiac
# 99       9          8  Premium         13  10087  Rolls-Royce
#
#                    model mpgData            trany  year
# 0     Spider Veloce 2000       Y     Manual 5-spd  1985
# 1             Testarossa       N     Manual 5-spd  1985
# ...

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#     year            trany mpgData                 model         make     id  \
# 0   1985     Manual 5-spd       Y    Spider Veloce 2000   Alfa Romeo      1
# 1   1985     Manual 5-spd       N            Testarossa      Ferrari     10
# 2   1985     Manual 5-spd       Y               Charger        Dodge    100
# 3   1985  Automatic 3-spd       N   B150/B250 Wagon 2WD        Dodge   1000
# 4   1993     Manual 5-spd       N      Legacy AWD Turbo       Subaru  10000
# ..   ...              ...     ...                   ...          ...    ...
# 95  1993  Automatic 3-spd       Y            Grand Prix      Pontiac  10083
# 96  1993  Automatic 4-spd       N            Grand Prix      Pontiac  10084
# 97  1993  Automatic 4-spd       N            Grand Prix      Pontiac  10085
# 98  1993     Manual 5-spd       N            Grand Prix      Pontiac  10086
# 99  1993  Automatic 4-spd       N  Brooklands/Brklnds L  Rolls-Royce  10087
#
#     highway08 fuelType  cylinders  city08
# ...

# %% [markdown]
# # Các hàm thống kê
#
# Tương tự như numpy thì Dataframe object cũng chứa các hàm thống kê
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
## Hàm mô tả tổng kết dữ liệu
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])
}

#Create a DataFrame
df = pd.DataFrame(d)

print(df)
# Out:
#       Name  Age  Rating
# 0      Tom   25    4.23
# 1    James   26    3.24
# 2    Ricky   25    3.98
# 3      Vin   23    2.56
# 4    Steve   30    3.20
# 5    Smith   29    4.60
# 6     Jack   23    3.80
# 7      Lee   34    3.78
# 8    David   40    2.98
# 9   Gasper   30    4.80
# 10  Betina   51    4.10
# 11  Andres   46    3.65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    12 non-null     object
#  1   Age     12 non-null     int64
#  2   Rating  12 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 416.0+ bytes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## Tổng kết dữ liệu có thể dùng tham số include với giá trị là: object, number hoặc all
df.describe()
# Out:
#              Age     Rating
# count  12.000000  12.000000
# mean   31.833333   3.743333
# std     9.232682   0.661628
# min    23.000000   2.560000
# 25%    25.000000   3.230000
# 50%    29.500000   3.790000
# 75%    35.500000   4.132500
# max    51.000000   4.800000

# %%
df.describe(include="object")
# Out:
#        Name
# count    12
# unique   12
# top     Tom
# freq      1

# %%
df.describe(include="all")
# Out:
#        Name        Age     Rating
# count    12  12.000000  12.000000
# unique   12        NaN        NaN
# top     Tom        NaN        NaN
# freq      1        NaN        NaN
# mean    NaN  31.833333   3.743333
# std     NaN   9.232682   0.661628
# min     NaN  23.000000   2.560000
# 25%     NaN  25.000000   3.230000
# 50%     NaN  29.500000   3.790000
# 75%     NaN  35.500000   4.132500
# max     NaN  51.000000   4.800000

# %%
df.describe(include='number')
# Out:
#              Age     Rating
# count  12.000000  12.000000
# mean   31.833333   3.743333
# std     9.232682   0.661628
# min    23.000000   2.560000
# 25%    25.000000   3.230000
# 50%    29.500000   3.790000
# 75%    35.500000   4.132500
# max    51.000000   4.800000

# %% [markdown]
# **Ngoài ra còn có các hàm như: info(), nunique(), unique(), value_counts()**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    12 non-null     object
#  1   Age     12 non-null     int64
#  2   Rating  12 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 416.0+ bytes

# %%
df['Age'].nunique()
# Out:
# 9

# %%
df["Age"].unique()
# Out:
# array([25, 26, 23, 30, 29, 34, 40, 51, 46])

# %%
df["Age"].value_counts()
# Out:
# 25    2
# 23    2
# 30    2
# 26    1
# 29    1
# 34    1
# 40    1
# 51    1
# 46    1
# Name: Age, dtype: int64

# %%
## Tính std value cho cột Age

df.Age.std()
# Out:
# 9.232682396921506

# %%
df["Age"].std()
# Out:
# 9.232682396921506

# %%
df["Age"].cumsum()
# Out:
# 0      25
# 1      51
# 2      76
# 3      99
# 4     129
# 5     158
# 6     181
# 7     215
# 8     255
# 9     285
# 10    336
# 11    382
# Name: Age, dtype: int64

# %%
df.Rating.median()
# Out:
# 3.79

# %%
df.Rating.mean()
# Out:
# 3.7433333333333327

# %%
df.Rating.prod()
# Out:
# 6320127.563709728

# %%
df.Rating.sum()
# Out:
# 44.919999999999995

# %% [markdown]
# ## pct_change()
#
# Hàm này tính phần trăm thay đổi của từng giá trị với giá trị đứng trước nó

# %%
s = pd.Series([1,2,3,4,5,4])
s.pct_change()
# Out:
# 0         NaN
# 1    1.000000
# 2    0.500000
# 3    0.333333
# 4    0.250000
# 5   -0.200000
# dtype: float64

# %%
s.pct_change?

# %%
import numpy as np

df = pd.DataFrame(np.random.randn(5, 2))
print(df)
df.pct_change()
# Out:
#           0         1
# 0  0.746618 -0.931545
# 1  0.195202 -0.313209
# 2 -0.201025 -0.302240
# 3  0.181095 -0.952728
# 4  2.341748 -0.629200
#            0         1
# 0        NaN       NaN
# 1  -0.738552 -0.663775
# 2  -2.029833 -0.035022
# 3  -1.900856  2.152229
# 4  11.931058 -0.339581

# %% [markdown]
# Mặc định thì hàm pct_change() áp dụng cho cột, muốn áp dụng cho hàng thì dùng axis=1

# %%
df.pct_change(axis=1)
# Out:
#     0         1
# 0 NaN -0.497523
# 1 NaN -0.650528
# 2 NaN -3.805570
# 3 NaN -0.823141
# 4 NaN  0.349327

# %% [markdown]
# ## cov(): Covariance
#
# Đối với Series thì hàm này thực hiện giữa các Series với nhau
#
# Đối với DataFrame thì hàm này thực hiện giữa các cột với nhau

# %%
import numpy as np

s1 = pd.Series(np.random.randn(10))
s2 = pd.Series(np.random.randn(10))
print(s1)
print(s2)

s1.cov(s2)
# Out:
# 0    1.607217
# 1   -0.967018
# 2   -0.955059
# 3    0.419530
# 4   -1.340142
# 5   -0.061871
# 6    0.261368
# 7    0.092083
# 8   -1.276296
# 9    0.582082
# dtype: float64
# 0   -0.666518
# 1   -1.459536
# 2    1.177184
# 3    0.052511
# 4    0.047183
# 5   -1.681548
# 6   -1.378985
# 7   -0.751055
# 8    0.402492
# 9   -1.014116
# dtype: float64
# -0.34650411884844706

# %%
df = pd.DataFrame(np.random.randn(10, 5), columns=['a', 'b', 'c', 'd', 'e'])
print(df)
print(df['a'].cov(df['b']))
print(df.cov())
# Out:
#           a         b         c         d         e
# 0  0.867028  1.383803 -1.509979 -0.006424 -0.548457
# 1 -1.158295  0.027474  0.872660 -0.320050 -0.059300
# 2 -0.972109  0.254982  0.644041 -0.899971  0.922134
# 3 -0.014813  0.026431  1.796748 -1.947800 -1.754502
# 4  1.050570  1.337226 -0.484456  0.890650  0.260342
# 5 -2.024225 -0.266800  0.363887 -0.812127  1.487874
# 6  0.451757  0.002394  0.320664  0.920687  0.406461
# 7  0.533827 -0.629629 -1.357153  0.214990  1.214349
# 8  0.270883 -0.065532 -0.260629  1.515915  1.296828
# 9  0.225911 -1.378565 -1.907739  0.495609 -0.598894
# 0.2504041190730252
#           a         b         c         d         e
# a  0.977116  0.250404 -0.601838  0.545082 -0.307284
# b  0.250404  0.677117  0.112093  0.021083 -0.091707
# c -0.601838  0.112093  1.385803 -0.711690 -0.186688
# d  0.545082  0.021083 -0.711690  1.066266  0.436044
# e -0.307284 -0.091707 -0.186688  0.436044  1.056082

# %% [markdown]
# ## corr(): Correlation
#
# Thể hiện được quan hệ tuyến tính giữa 2 mảng giá trị (Series).

# %%
df = pd.DataFrame(np.random.randn(10, 5), columns=['a', 'b', 'c', 'd', 'e'])
print(df)
df['a'].corr(df['b'])
# Out:
#           a         b         c         d         e
# 0  2.233333  0.364965 -0.967937 -0.424671  1.587424
# 1  2.367965 -0.484690  0.451440  0.071691 -0.344225
# 2 -0.478908 -1.325999  1.349017  0.562867 -0.529857
# 3 -0.035885 -0.439582 -0.416052  0.561090  1.077604
# 4 -0.834939  0.705299  1.590252  1.769386  0.092145
# 5 -0.740111  0.222583 -0.244455  0.318350  1.214140
# 6 -0.243209  0.430342  0.543044 -0.694155  1.148059
# 7 -0.293401 -0.206949 -2.274977  0.930229 -0.260586
# 8 -0.617131  0.830894 -0.699491 -0.663034 -0.963591
# 9 -0.115554 -0.740341  0.077545  0.379160  0.777785
# -0.11306824487998032

# %%
df.corr()
# Out:
#           a         b         c         d         e
# a  1.000000 -0.113068 -0.152651 -0.356870  0.192213
# b -0.113068  1.000000 -0.153137 -0.213146  0.132140
# c -0.152651 -0.153137  1.000000  0.240662 -0.091638
# d -0.356870 -0.213146  0.240662  1.000000 -0.168136
# e  0.192213  0.132140 -0.091638 -0.168136  1.000000

# %% [markdown]
# ## rank()
#
# Thực hiện xếp hạng mỗi thành phần trong mảng. Trong trường hợp có rằng buộc, sử dụng mean rank.

# %%
df = pd.Series(np.random.randn(5), index=list('abcde'))
print(df)
df.rank()
# Out:
# a    0.636470
# b   -0.611155
# c   -0.162415
# d    1.318878
# e    1.800657
# dtype: float64
# a    3.0
# b    1.0
# c    2.0
# d    4.0
# e    5.0
# dtype: float64

# %%
df['d'] = df['b']
print(df)
df.rank()
# Out:
# a    0.636470
# b   -0.611155
# c   -0.162415
# d   -0.611155
# e    1.800657
# dtype: float64
# a    4.0
# b    1.5
# c    3.0
# d    1.5
# e    5.0
# dtype: float64

# %% [markdown]
# # Window functions
#
# - Ngoài các hàm thống kê bên trên, pandas cung cấp các biến thể như: **rolling, expanding và exponentially moving weights** cho window statistics.

# %% [markdown]
# ## .rolling()
#
# Hàm này dùng để thực thi trên series của data. Xác định tham số **window=n** và áp dụng cho 1 hàm thông kê nào đó.

# %%
import numpy as np

df = pd.DataFrame(np.random.randn(10, 4),
   index = pd.date_range('1/1/2000', periods=10),
   columns = ['A', 'B', 'C', 'D'])
df
# Out:
#                    A         B         C         D
# 2000-01-01 -0.529557 -0.558390 -0.725733  0.833319
# 2000-01-02 -0.895114 -1.115931  1.444083 -0.724572
# 2000-01-03 -0.263311 -0.062005 -1.332581 -0.379790
# 2000-01-04 -1.167107 -1.018116 -1.059938 -0.229275
# 2000-01-05 -0.505712 -0.973295  0.757467  0.046118
# 2000-01-06  0.416508 -0.713904 -1.961094 -0.354634
# 2000-01-07  0.071376 -1.277654 -0.694936 -0.443995
# 2000-01-08 -0.632699 -0.236513  1.011342 -0.568969
# 2000-01-09 -0.900148  1.059035  0.887603  1.649700
# 2000-01-10 -1.096940  0.245190  0.499563 -0.136598

# %%
pd.date_range?

# %%
df.rolling(window=3).sum()
# Out:
#                    A         B         C         D
# 2000-01-01       NaN       NaN       NaN       NaN
# 2000-01-02       NaN       NaN       NaN       NaN
# 2000-01-03 -1.687981 -1.736326 -0.614232 -0.271043
# 2000-01-04 -2.325532 -2.196051 -0.948437 -1.333637
# 2000-01-05 -1.936129 -2.053416 -1.635052 -0.562948
# 2000-01-06 -1.256310 -2.705315 -2.263565 -0.537792
# 2000-01-07 -0.017828 -2.964854 -1.898563 -0.752511
# 2000-01-08 -0.144815 -2.228071 -1.644688 -1.367598
# 2000-01-09 -1.461471 -0.455132  1.204009  0.636736
# 2000-01-10 -2.629787  1.067712  2.398508  0.944133

# %% [markdown]
# Vì window=3 nên 2 giá trị đầu = NaN, giá trị thứ 3 = trung bình của n, n-1, n-2

# %%
df["A_mean"] = df["A"].rolling(window=2).mean()
df
# Out:
#                    A         B         C         D    A_mean
# 2000-01-01 -0.529557 -0.558390 -0.725733  0.833319       NaN
# 2000-01-02 -0.895114 -1.115931  1.444083 -0.724572 -0.712335
# 2000-01-03 -0.263311 -0.062005 -1.332581 -0.379790 -0.579212
# 2000-01-04 -1.167107 -1.018116 -1.059938 -0.229275 -0.715209
# 2000-01-05 -0.505712 -0.973295  0.757467  0.046118 -0.836409
# 2000-01-06  0.416508 -0.713904 -1.961094 -0.354634 -0.044602
# 2000-01-07  0.071376 -1.277654 -0.694936 -0.443995  0.243942
# 2000-01-08 -0.632699 -0.236513  1.011342 -0.568969 -0.280661
# 2000-01-09 -0.900148  1.059035  0.887603  1.649700 -0.766424
# 2000-01-10 -1.096940  0.245190  0.499563 -0.136598 -0.998544

# %% [markdown]
# ## .expanding()
#
# Tích lũy giá trị để tính hàm được chọn

# %%
df.expanding?

# %%
df = pd.DataFrame(np.arange(0, 40).reshape(10, 4),
   index = pd.date_range('1/1/2000', periods=10),
   columns = ['A', 'B', 'C', 'D'])
df
# Out:
#              A   B   C   D
# 2000-01-01   0   1   2   3
# 2000-01-02   4   5   6   7
# 2000-01-03   8   9  10  11
# 2000-01-04  12  13  14  15
# 2000-01-05  16  17  18  19
# 2000-01-06  20  21  22  23
# 2000-01-07  24  25  26  27
# 2000-01-08  28  29  30  31
# 2000-01-09  32  33  34  35
# 2000-01-10  36  37  38  39

# %%
df.expanding(min_periods=1).sum()
# Out:
#                 A      B      C      D
# 2000-01-01    0.0    1.0    2.0    3.0
# 2000-01-02    4.0    6.0    8.0   10.0
# 2000-01-03   12.0   15.0   18.0   21.0
# 2000-01-04   24.0   28.0   32.0   36.0
# 2000-01-05   40.0   45.0   50.0   55.0
# 2000-01-06   60.0   66.0   72.0   78.0
# 2000-01-07   84.0   91.0   98.0  105.0
# 2000-01-08  112.0  120.0  128.0  136.0
# 2000-01-09  144.0  153.0  162.0  171.0
# 2000-01-10  180.0  190.0  200.0  210.0

# %%
df.expanding(min_periods=2).sum()
# Out:
#                 A      B      C      D
# 2000-01-01    NaN    NaN    NaN    NaN
# 2000-01-02    4.0    6.0    8.0   10.0
# 2000-01-03   12.0   15.0   18.0   21.0
# 2000-01-04   24.0   28.0   32.0   36.0
# 2000-01-05   40.0   45.0   50.0   55.0
# 2000-01-06   60.0   66.0   72.0   78.0
# 2000-01-07   84.0   91.0   98.0  105.0
# 2000-01-08  112.0  120.0  128.0  136.0
# 2000-01-09  144.0  153.0  162.0  171.0
# 2000-01-10  180.0  190.0  200.0  210.0

# %%
df.expanding(min_periods=3).sum()
# Out:
#                 A      B      C      D
# 2000-01-01    NaN    NaN    NaN    NaN
# 2000-01-02    NaN    NaN    NaN    NaN
# 2000-01-03   12.0   15.0   18.0   21.0
# 2000-01-04   24.0   28.0   32.0   36.0
# 2000-01-05   40.0   45.0   50.0   55.0
# 2000-01-06   60.0   66.0   72.0   78.0
# 2000-01-07   84.0   91.0   98.0  105.0
# 2000-01-08  112.0  120.0  128.0  136.0
# 2000-01-09  144.0  153.0  162.0  171.0
# 2000-01-10  180.0  190.0  200.0  210.0

# %% [markdown]
# # .map()
#
# **Series.map(self, arg, na_action=None)**
#
# The map() function is used to map values of Series according to input correspondence.
#
# Used for substituting each value in a Series with another value, that may be derived from a function, a dict or a Series.

# %%
s = pd.Series(['fox', 'cow', np.nan, 'dog'])
s
# Out:
# 0    fox
# 1    cow
# 2    NaN
# 3    dog
# dtype: object

# %%
s.map({'fox': 'cub', 'cow': 'calf'})
# Out:
# 0     cub
# 1    calf
# 2     NaN
# 3     NaN
# dtype: object

# %%
s.map({'fox': 'cub', 'cow': 'calf', np.nan: '12'})
# Out:
# 0     cub
# 1    calf
# 2      12
# 3     NaN
# dtype: object

# %%
## Nó cũng chấp nhận hàm

s.map('I am a {}'.format)
# Out:
# 0    I am a fox
# 1    I am a cow
# 2    I am a nan
# 3    I am a dog
# dtype: object

# %%
## Để tránh map giá trị NaN vào hàm thì dùng:

s.map('I am a {}'.format, na_action='ignore')
# Out:
# 0    I am a fox
# 1    I am a cow
# 2           NaN
# 3    I am a dog
# dtype: object

# %% [markdown]
# # .apply()
#
# Gọi hàm python thực thi trên giá trị của series. Có thể dùng cả hàm không tên làm tham số (lambda)
#
# **Series.apply(self, func, convert_dtype=True, args=(), **kwds)**

# %%
s = pd.Series([31, 27, 11], index=['Beijing', 'Los Angeles', 'Berlin'])
s
# Out:
# Beijing        31
# Los Angeles    27
# Berlin         11
# dtype: int64

# %%
def square(x):
    return x**2

s.apply(square)
# Out:
# Beijing        961
# Los Angeles    729
# Berlin         121
# dtype: int64

# %%
s.apply(lambda x: x**2)
# Out:
# Beijing        961
# Los Angeles    729
# Berlin         121
# dtype: int64

# %%
s.apply(lambda x: str(x))
# Out:
# Beijing        31
# Los Angeles    27
# Berlin         11
# dtype: object

# %% [markdown]
# - Còn thêm được cả hàm có 1 hoặc nhiều tham số
# - Hoặc dùng các hàm của numpy

# %%
print(s)

def sub_value(x, value):
    return x - value

s.apply(sub_value, args=(5, ))
# Out:
# Beijing        31
# Los Angeles    27
# Berlin         11
# dtype: int64
# Beijing        26
# Los Angeles    22
# Berlin          6
# dtype: int64

# %%
s = pd.Series([31, 27, 11, 14], index=['Beijing', 'Los Angeles', 'Berlin', "vietnam"])
print(s)
# Out:
# Beijing        31
# Los Angeles    27
# Berlin         11
# vietnam        14
# dtype: int64

# %%
def add_value(x, **kwargs):
    print(kwargs)
    for month in kwargs:
        x += kwargs[month]
    return x

s.apply(add_value, november=1, december=2, january=3, negative=-6)
# Out:
# {'november': 1, 'december': 2, 'january': 3, 'negative': -6}
# {'november': 1, 'december': 2, 'january': 3, 'negative': -6}
# {'november': 1, 'december': 2, 'january': 3, 'negative': -6}
# {'november': 1, 'december': 2, 'january': 3, 'negative': -6}
# Beijing        31
# Los Angeles    27
# Berlin         11
# vietnam        14
# dtype: int64

# %%
s.apply(np.log)
# Out:
# Beijing        3.433987
# Los Angeles    3.295837
# Berlin         2.397895
# dtype: float64

# %%
print(s)
s.apply(np.exp)
# Out:
# Beijing        31
# Los Angeles    27
# Berlin         11
# dtype: int64
# Beijing        2.904885e+13
# Los Angeles    5.320482e+11
# Berlin         5.987414e+04
# dtype: float64

# %%
s.apply(np.sin)
# Out:
# Beijing       -0.404038
# Los Angeles    0.956376
# Berlin        -0.999990
# dtype: float64

# %% [markdown]
# # .agg() / .aggregate()
#
# **Series.agg(self, func, axis=0, *args, **kwargs)**
#
# The agg() function uses one or more operations over the specified axis.

# %%
s = pd.Series([2, 4, 6, 8])
s.agg('min')
# Out:
# 2

# %%
s.agg(['min', 'max'])
# Out:
# min    2
# max    8
# dtype: int64

# %%
s.aggregate('min')
# Out:
# 2

# %%
s.aggregate(["min", "max"])
# Out:
# min    2
# max    8
# dtype: int64

# %%
s.aggregate(["min", "mean", "median", "max", "std"])
# Out:
# min       2.000000
# mean      5.000000
# median    5.000000
# max       8.000000
# std       2.581989
# dtype: float64

# %%
s.min()
s.mean()
s.max()
s.median()
s.std()
# Out:
# 2.581988897471611

# %% [markdown]
# # .transform()
#
# **Series.transform(self, func, axis=0, *args, **kwargs)**
#
# The transform() function is used to call function on self producing a Series with transformed values and that has the same axis length as self.

# %%
df = pd.DataFrame({'P': range(4), 'Q': range(2, 6)})
df
# Out:
#    P  Q
# 0  0  2
# 1  1  3
# 2  2  4
# 3  3  5

# %%
def add(x):
    return x + 2

# %%
df.transform(lambda x: x + 2)
# Out:
#    P  Q
# 0  2  4
# 1  3  5
# 2  4  6
# 3  5  7

# %%
df.apply(lambda x: x+2)
# Out:
#    P  Q
# 0  2  4
# 1  3  5
# 2  4  6
# 3  5  7

# %%
df.transform([np.sqrt, np.exp])
# Out:
#           P                    Q
#        sqrt        exp      sqrt         exp
# 0  0.000000   1.000000  1.414214    7.389056
# 1  1.000000   2.718282  1.732051   20.085537
# 2  1.414214   7.389056  2.000000   54.598150
# 3  1.732051  20.085537  2.236068  148.413159

# %%
df.apply([np.sqrt, np.exp])
# Out:
#           P                    Q
#        sqrt        exp      sqrt         exp
# 0  0.000000   1.000000  1.414214    7.389056
# 1  1.000000   2.718282  1.732051   20.085537
# 2  1.414214   7.389056  2.000000   54.598150
# 3  1.732051  20.085537  2.236068  148.413159

# %% [markdown]
# # apply # transform
#
# (1): Giống nhau
#
# - transform() works with function, a string function, a list of functions, and a dict. However, apply() is only allowed with function.
#
#
# (2): Khác nhau
#
# - transform() cannot produce aggregated results.
#
# - apply() works with multiple Series at a time. But, transform() is only allowed to work with a single Series at a time.

# %%
## Giống nhau

print(df.transform('sqrt'))
print(df.transform([np.sqrt, np.exp]))
print(df.transform({
    'P': np.sqrt,
    'Q': np.exp,
}))
# Out:
#           P         Q
# 0  0.000000  1.414214
# 1  1.000000  1.732051
# 2  1.414214  2.000000
# 3  1.732051  2.236068
#           P                    Q
#        sqrt        exp      sqrt         exp
# 0  0.000000   1.000000  1.414214    7.389056
# 1  1.000000   2.718282  1.732051   20.085537
# 2  1.414214   7.389056  2.000000   54.598150
# 3  1.732051  20.085537  2.236068  148.413159
#           P           Q
# 0  0.000000    7.389056
# 1  1.000000   20.085537
# 2  1.414214   54.598150
# 3  1.732051  148.413159

# %%
df.apply({
    'P': np.sqrt,
    'Q': np.exp,
})
# Out:
#           P           Q
# 0  0.000000    7.389056
# 1  1.000000   20.085537
# 2  1.414214   54.598150
# 3  1.732051  148.413159

# %%
## Khác nhau

df.apply(lambda x:x.sum())
# Out:
# P     6
# Q    14
# dtype: int64

# %%
df.transform(lambda x:x.sum())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-f4024d838c46> in <cell line: 1>()
# ----> 1 df.transform(lambda x:x.sum())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in transform(self, func, axis, *args, **kwargs)
#    9260
#    9261         op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 9262         result = op.transform()
#    9263         assert isinstance(result, DataFrame)
#    9264         return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform(self)
#     237             obj.index  # type:ignore[arg-type]
#     238         ):
# --> 239             raise ValueError("Function did not transform")
#     240
#     241         return result
#
# ValueError: Function did not transform

# %%
# It is working
df.apply(lambda x: x['Q'] - x['P'], axis=1)
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# dtype: int64

# %%
# Getting error
df.transform(lambda x: x['Q'] - x['P'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-caa239706bdd> in <cell line: 2>()
#       1 # Getting error
# ----> 2 df.transform(lambda x: x['Q'] - x['P'], axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in transform(self, func, axis, *args, **kwargs)
#    9260
#    9261         op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 9262         result = op.transform()
#    9263         assert isinstance(result, DataFrame)
#    9264         return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in transform(self)
#     199         if obj._get_axis_number(axis) == 1:
#     200             assert not is_series
# --> 201             return obj.T.transform(func, 0, *args, **kwargs).T
#     202
#     203         if is_list_like(func) and not is_dict_like(func):
#
# ...

# %% [markdown]
# ## Kết hợp với groupby()
#
# Cả 2 apply() và transform() đều kết hợp được với groupby(). Tuy nhiên:
#
# - transform() returns a DataFrame that has the same length as the input
#
# - apply() works with multiple Series at a time. But, transform() is only allowed to work with a single Series at a time.

# %%
df = pd.DataFrame({
    'key': ['a','b','c'] * 4,
    'A': np.arange(12),
    'B': [1,2,3] * 4,
})
df
# Out:
#    key   A  B
# 0    a   0  1
# 1    b   1  2
# 2    c   2  3
# 3    a   3  1
# 4    b   4  2
# 5    c   5  3
# 6    a   6  1
# 7    b   7  2
# 8    c   8  3
# 9    a   9  1
# 10   b  10  2
# 11   c  11  3

# %%
## (1) transform() returns a Series that has the same length as the input

# Aggregating the sum of the given Series
def group_sum(x):
    return x.sum()

# %%
gr_data_ap = df.groupby('key')['A'].apply(group_sum)
gr_data_ap
# Out:
# key
# a    18
# b    22
# c    26
# Name: A, dtype: int64

# %%
gr_data_tr = df.groupby('key')['A'].transform(group_sum)
gr_data_tr
# Out:
# 0     18
# 1     22
# 2     26
# 3     18
# 4     22
# 5     26
# 6     18
# 7     22
# 8     26
# 9     18
# 10    22
# 11    26
# Name: A, dtype: int64

# %%
## (2) apply() works with multiple Series at a time. But transform() is only allowed to work with a single Series at a time.

def subtract_two(x):
    return x['B'] - x['A']

# %%
df.groupby('key').apply(subtract_two)
# Out:
# key
# a    0     1
#      3    -2
#      6    -5
#      9    -8
# b    1     1
#      4    -2
#      7    -5
#      10   -8
# c    2     1
#      5    -2
#      8    -5
#      11   -8
# dtype: int64

# %%
df.groupby('key').transform(subtract_two)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'B'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-0b8be0af7c2f> in <module>
# ----> 1 df.groupby('key').transform(subtract_two)
#
# ...

# %% [markdown]
# # groupby()
#
# **DataFrame.groupby(by=None, axis=0, level=None, as_index=True, sort=True, group_keys=True, squeeze=False, **kwargs)**
#
#
# Sử dụng để chia nhỏ data thành các group dựa trên tiêu chí nào đó, các thao tác như:
#
# - Chi nhỏ dữ liệu
# - Phân tích dữ liệu
# - Tổng hợp, tích hợp dữ liệu
#
# Trong nhiều trường hợp, ta chia nhỏ bộ dữ liệu thành nhiều tập. Thực thi các hàm trên các tập đó, các hàm có thể là:
#
# - Tập hợp, các hàm thống kê (Aggregation)
# - Chuyển đổi, chuyển vị (Transformation)
# - Bộ lọc (Filtration

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings',
   'Kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
   'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
   'Year': [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
   'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}

df = pd.DataFrame(ipl_data)
print(df)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %% [markdown]
# ## Chia nhỏ thành các group
#
# obj.groupby('key')
#
# obj.groupby(['key1', 'key2'])
#
# obj.groupby(key, axis=1)

# %%
df.groupby('Team')

# %%
df.groupby('Team').groups
# Out:
# {'Devils': [2, 3], 'Kings': [4, 5, 6, 7], 'Riders': [0, 1, 8, 11], 'Royals': [9, 10]}

# %%
## Chia dựa vào nhiều cột

df.groupby(['Team', 'Year']).groups
# Out:
# {('Devils', 2014): [2], ('Devils', 2015): [3], ('Kings', 2014): [4], ('Kings', 2015): [5], ('Kings', 2016): [6], ('Kings', 2017): [7], ('Riders', 2014): [0], ('Riders', 2015): [1], ('Riders', 2016): [8], ('Riders', 2017): [11], ('Royals', 2014): [9], ('Royals', 2015): [10]}

# %%
## Lặp qua groups

grouped = df.groupby('Year')

for name, group in grouped:
   print(f'{name}: {group}')
   print(f'{type(group)} \n')
# Out:
# 2014:      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701
# <class 'pandas.core.frame.DataFrame'>
#
# 2015:       Team  Rank  Year  Points
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    Kings     4  2015     812
# 10  Royals     1  2015     804
# <class 'pandas.core.frame.DataFrame'>
#
# 2016:      Team  Rank  Year  Points
# 6   Kings     1  2016     756
# 8  Riders     2  2016     694
# <class 'pandas.core.frame.DataFrame'>
#
# 2017:       Team  Rank  Year  Points
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Chọn group
#
# Sử dụng hàm: get_group()

# %%
groups = df.groupby('Year')
print(groups.get_group(2014))
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701

# %% [markdown]
# ## Tổng hợp: agg()
#
# Hàm tổng hợp trả lại giá trị tổng hợp của mỗi group.
#
# - It is defined as a function that returns a single aggregated value for each of the groups. We can perform several aggregation operations on the grouped data when the groupby object is created.

# %%
import numpy as np

grouped = df.groupby('Year')
grouped['Points'].agg(np.mean)
# Out:
# Year
# 2014    795.25
# 2015    769.50
# 2016    725.00
# 2017    739.00
# Name: Points, dtype: float64

# %%
df.groupby("Year")['Points'].agg(np.mean)
# Out:
# Year
# 2014    795.25
# 2015    769.50
# 2016    725.00
# 2017    739.00
# Name: Points, dtype: float64

# %%
## Dùng hàm size để xem kích thước mỗi nhóm

groups = df.groupby('Team')
groups.agg(np.size)
# Out:
#         Rank  Year  Points
# Team
# Devils     2     2       2
# Kings      4     4       4
# Riders     4     4       4
# Royals     2     2       2

# %%
df.groupby("Team").agg(np.size)
# Out:
#         Rank  Year  Points
# Team
# Devils     2     2       2
# Kings      4     4       4
# Riders     4     4       4
# Royals     2     2       2

# %% [markdown]
# ### Tổng hợp nhiều hàm cùng lúc
#
# Có thể truyền một list hoặc dict functions để thực thi tổng hợp.

# %%
groups = df.groupby('Team')
print(groups['Points'].agg([np.sum, np.mean, np.std]))
# Out:
#          sum    mean         std
# Team
# Devils  1536  768.00  134.350288
# Kings   3097  774.25   31.899582
# Riders  3049  762.25   88.567771
# Royals  1505  752.50   72.831998

# %%
df.groupby("Team")["Points"].agg([np.sum, np.mean, np.std])
# Out:
#          sum    mean         std
# Team
# Devils  1536  768.00  134.350288
# Kings   3097  774.25   31.899582
# Riders  3049  762.25   88.567771
# Royals  1505  752.50   72.831998

# %% [markdown]
# ## Transformations (biến đổi)
#
# Biến đổi trên một group hoặc một cột trả về một object được lập chỉ mục có cùng kích thước với object đang được nhóm. Do đó, phép biến đổi sẽ trả về kết quả có cùng kích thước với kết quả của các nhóm được biến đổi

# %%
print(df)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
groups = df.groupby("Team")
for name, group in groups:
   print(f'{name}: {group}')
   print(f'{type(group)} \n')

groups["Points"].transform(lambda x: x.mean())
# Out:
# Devils:      Team  Rank  Year  Points
# 2  Devils     2  2014     863
# 3  Devils     3  2015     673
# <class 'pandas.core.frame.DataFrame'>
#
# Kings:     Team  Rank  Year  Points
# 4  Kings     3  2014     741
# 5  Kings     4  2015     812
# 6  Kings     1  2016     756
# 7  Kings     1  2017     788
# <class 'pandas.core.frame.DataFrame'>
#
# Riders:       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 8   Riders     2  2016     694
# 11  Riders     2  2017     690
# <class 'pandas.core.frame.DataFrame'>
#
# Royals:       Team  Rank  Year  Points
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# <class 'pandas.core.frame.DataFrame'>
# 0     762.25
# 1     762.25
# 2     768.00
# 3     768.00
# 4     774.25
# 5     774.25
# 6     774.25
# 7     774.25
# 8     762.25
# 9     752.50
# 10    752.50
# 11    762.25
# Name: Points, dtype: float64

# %% [markdown]
# ## Bộ lọc: filter()
#
# The filter() function filters the data by defining some criteria and returns the subset of data.

# %%
print(df)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2015     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
df.groupby("Team").filter(lambda x: len(x) >= 3)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 4    Kings     3  2014     741
# 5    Kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 11  Riders     2  2017     690

# %% [markdown]
# ## Ví dụ khác
#
# Để biến bảng mua bán sản phẩm thành như sau:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Có 2 cách có thể nghĩ đến là:
#
# 1. Sử dụng Groupby theo sau là merge()
# 2. Sử dụng transform()

# %% [markdown]
# **Sử dụng groupby() theo sau là merge()**

# %%
data = {
    "User_ID": [1001, 1001, 1001, 1001, 1002, 1003, 1004, 1004, 1004, 1004, 1005, 1005, 1005, 1005, 1005],
    "Product_ID": ["P1", "P2", "P3", "P4", "P2", "P3", "P1", "P2", "P3", "P4", "P1", "P2", "P3", "P4", "P5"],
    "Purchase": [100, 200, 300, 500, 200, 400, 200, 300, 400, 500, 100, 200, 300, 400, 500],
}
df = pd.DataFrame(data)
print(df)
# Out:
#     User_ID Product_ID  Purchase
# 0      1001         P1       100
# 1      1001         P2       200
# 2      1001         P3       300
# 3      1001         P4       500
# 4      1002         P2       200
# 5      1003         P3       400
# 6      1004         P1       200
# 7      1004         P2       300
# 8      1004         P3       400
# 9      1004         P4       500
# 10     1005         P1       100
# 11     1005         P2       200
# 12     1005         P3       300
# 13     1005         P4       400
# 14     1005         P5       500

# %%
groups = df.groupby("User_ID")["Purchase"].mean()
print(groups)
# Out:
# User_ID
# 1001    275.0
# 1002    200.0
# 1003    400.0
# 1004    350.0
# 1005    300.0
# Name: Purchase, dtype: float64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
mean_purchase = groups.rename("User_mean").reset_index()
df1 = df.merge(mean_purchase)
print(df1)
# Out:
#     User_ID Product_ID  Purchase  User_mean
# 0      1001         P1       100      275.0
# 1      1001         P2       200      275.0
# 2      1001         P3       300      275.0
# 3      1001         P4       500      275.0
# 4      1002         P2       200      200.0
# 5      1003         P3       400      400.0
# 6      1004         P1       200      350.0
# 7      1004         P2       300      350.0
# 8      1004         P3       400      350.0
# 9      1004         P4       500      350.0
# 10     1005         P1       100      300.0
# 11     1005         P2       200      300.0
# 12     1005         P3       300      300.0
# 13     1005         P4       400      300.0
# 14     1005         P5       500      300.0

# %% [markdown]
# **Sử dụng transform function()**

# %%
df["User_Mean"] = df.groupby('User_ID')["Purchase"].transform('mean')
print(df)
# Out:
#     User_ID Product_ID  Purchase  User_Mean
# 0      1001         P1       100      275.0
# 1      1001         P2       200      275.0
# 2      1001         P3       300      275.0
# 3      1001         P4       500      275.0
# 4      1002         P2       200      200.0
# 5      1003         P3       400      400.0
# 6      1004         P1       200      350.0
# 7      1004         P2       300      350.0
# 8      1004         P3       400      350.0
# 9      1004         P4       500      350.0
# 10     1005         P1       100      300.0
# 11     1005         P2       200      300.0
# 12     1005         P3       300      300.0
# 13     1005         P4       400      300.0
# 14     1005         P5       500      300.0

# %% [markdown]
# # Cleaning data
#
# 1. Clean empty cells
# 2. Clean wrong format
# 3. Clean wrong data
# 4. Clean duplicates
#
# Dataset link: https://github.com/thieu1995/csv-files/blob/main/data/pandas/gymmer.csv

# %%
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/gymmer.csv")

data.describe()
# Out:
#            Index    Duration       Pulse    Maxpulse    Calories
# count  32.000000   32.000000   32.000000   32.000000   30.000000
# mean   15.500000   68.437500  103.500000  128.500000  304.680000
# std     9.380832   70.039591    7.832933   12.998759   66.003779
# min     0.000000   30.000000   90.000000  101.000000  195.100000
# 25%     7.750000   60.000000  100.000000  120.000000  250.700000
# 50%    15.500000   60.000000  102.500000  127.500000  291.200000
# 75%    23.250000   60.000000  106.500000  132.250000  343.975000
# max    31.000000  450.000000  130.000000  175.000000  479.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Index     32 non-null     int64
#  1   Duration  32 non-null     int64
#  2   Date      31 non-null     object
#  3   Pulse     32 non-null     int64
#  4   Maxpulse  32 non-null     int64
#  5   Calories  30 non-null     float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 1.6+ KB

# %%
data.head()
# Out:
#    Index  Duration          Date  Pulse  Maxpulse  Calories
# 0      0        60  '2020/12/01'    110       130     409.1
# 1      1        60  '2020/12/02'    117       145     479.0
# 2      2        60  '2020/12/03'    103       135     340.0
# 3      3        45  '2020/12/04'    109       175     282.4
# 4      4        45  '2020/12/05'    117       148     406.0

# %%
data[data.isna().any(axis=1)]
# Out:
#     Index  Duration          Date  Pulse  Maxpulse  Calories
# 18     18        45  '2020/12/18'     90       112       NaN
# 22     22        45           NaN    100       119     282.0
# 28     28        60  '2020/12/28'    103       132       NaN

# %% [markdown]
# ## Clean empty cells
#
# - Nếu data lớn có thể xóa empty cells bằng cách remove cả hàng.
# - Nếu data nhỏ thì nên thay thế empty cells bằng giá trị khác.

# %%
data.dropna(inplace=False)   # True: thực thi trên data
# Out:
#     Index  Duration          Date  Pulse  Maxpulse  Calories
# 0       0        60  '2020/12/01'    110       130     409.1
# 1       1        60  '2020/12/02'    117       145     479.0
# 2       2        60  '2020/12/03'    103       135     340.0
# 3       3        45  '2020/12/04'    109       175     282.4
# 4       4        45  '2020/12/05'    117       148     406.0
# 5       5        60  '2020/12/06'    102       127     300.0
# 6       6        60  '2020/12/07'    110       136     374.0
# 7       7       450  '2020/12/08'    104       134     253.3
# 8       8        30  '2020/12/09'    109       133     195.1
# 9       9        60  '2020/12/10'     98       124     269.0
# 10     10        60  '2020/12/11'    103       147     329.3
# 11     11        60  '2020/12/12'    100       120     250.7
# 12     12        60  '2020/12/12'    100       120     250.7
# 13     13        60  '2020/12/13'    106       128     345.3
# ...

# %%
data.fillna(130, inplace=False)         # inplace=True: thực thi trên original data
# Out:
#     Index  Duration          Date  Pulse  Maxpulse  Calories
# 0       0        60  '2020/12/01'    110       130     409.1
# 1       1        60  '2020/12/02'    117       145     479.0
# 2       2        60  '2020/12/03'    103       135     340.0
# 3       3        45  '2020/12/04'    109       175     282.4
# 4       4        45  '2020/12/05'    117       148     406.0
# 5       5        60  '2020/12/06'    102       127     300.0
# 6       6        60  '2020/12/07'    110       136     374.0
# 7       7       450  '2020/12/08'    104       134     253.3
# 8       8        30  '2020/12/09'    109       133     195.1
# 9       9        60  '2020/12/10'     98       124     269.0
# 10     10        60  '2020/12/11'    103       147     329.3
# 11     11        60  '2020/12/12'    100       120     250.7
# 12     12        60  '2020/12/12'    100       120     250.7
# 13     13        60  '2020/12/13'    106       128     345.3
# ...

# %% [markdown]
# - Thực thi cho một column nhất định bằng cách chọn column đó.

# %%
data["Calories"].fillna(130, inplace = True)
# Out:
# 0     409.1
# 1     479.0
# 2     340.0
# 3     282.4
# 4     406.0
# 5     300.0
# 6     374.0
# 7     253.3
# 8     195.1
# 9     269.0
# 10    329.3
# 11    250.7
# 12    250.7
# 13    345.3
# 14    379.3
# 15    275.0
# 16    215.2
# 17    300.0
# 18    130.0
# 19    323.0
# 20    243.0
# 21    364.2
# 22    282.0
# 23    300.0
# 24    246.0
# 25    334.5
# 26    250.0
# 27    241.0
# 28    130.0
# 29    280.0
# 30    380.3
# 31    243.0
# Name: Calories, dtype: float64

# %% [markdown]
# - Có thể thay thế bằng các giá trị như: Mean, Median, Mode

# %%
x1 = data["Calories"].mean()
x2 = data["Calories"].median()
x3 = data["Calories"].mode()

data["Calories"].fillna(x1, inplace = True)

# %% [markdown]
# ## Clean wrong format

# %%
data['Date'] = pd.to_datetime(data['Date'])

print(data.to_string())
# Out:
#     Index  Duration       Date  Pulse  Maxpulse  Calories
# 0       0        60 2020-12-01    110       130     409.1
# 1       1        60 2020-12-02    117       145     479.0
# 2       2        60 2020-12-03    103       135     340.0
# 3       3        45 2020-12-04    109       175     282.4
# 4       4        45 2020-12-05    117       148     406.0
# 5       5        60 2020-12-06    102       127     300.0
# 6       6        60 2020-12-07    110       136     374.0
# 7       7       450 2020-12-08    104       134     253.3
# 8       8        30 2020-12-09    109       133     195.1
# 9       9        60 2020-12-10     98       124     269.0
# 10     10        60 2020-12-11    103       147     329.3
# 11     11        60 2020-12-12    100       120     250.7
# 12     12        60 2020-12-12    100       120     250.7
# 13     13        60 2020-12-13    106       128     345.3
# 14     14        60 2020-12-14    104       132     379.3
# ...

# %%
data.dropna(subset=['Date'], inplace = True)
data
# Out:
#     Index  Duration       Date  Pulse  Maxpulse  Calories
# 0       0        60 2020-12-01    110       130     409.1
# 1       1        60 2020-12-02    117       145     479.0
# 2       2        60 2020-12-03    103       135     340.0
# 3       3        45 2020-12-04    109       175     282.4
# 4       4        45 2020-12-05    117       148     406.0
# 5       5        60 2020-12-06    102       127     300.0
# 6       6        60 2020-12-07    110       136     374.0
# 7       7       450 2020-12-08    104       134     253.3
# 8       8        30 2020-12-09    109       133     195.1
# 9       9        60 2020-12-10     98       124     269.0
# 10     10        60 2020-12-11    103       147     329.3
# 11     11        60 2020-12-12    100       120     250.7
# 12     12        60 2020-12-12    100       120     250.7
# 13     13        60 2020-12-13    106       128     345.3
# 14     14        60 2020-12-14    104       132     379.3
# ...

# %% [markdown]
# ## Clean wrong data

# %%
data.loc[7, 'Duration'] = 45
data
# Out:
#     Index  Duration       Date  Pulse  Maxpulse  Calories
# 0       0        60 2020-12-01    110       130     409.1
# 1       1        60 2020-12-02    117       145     479.0
# 2       2        60 2020-12-03    103       135     340.0
# 3       3        45 2020-12-04    109       175     282.4
# 4       4        45 2020-12-05    117       148     406.0
# 5       5        60 2020-12-06    102       127     300.0
# 6       6        60 2020-12-07    110       136     374.0
# 7       7        45 2020-12-08    104       134     253.3
# 8       8        30 2020-12-09    109       133     195.1
# 9       9        60 2020-12-10     98       124     269.0
# 10     10        60 2020-12-11    103       147     329.3
# 11     11        60 2020-12-12    100       120     250.7
# 12     12        60 2020-12-12    100       120     250.7
# 13     13        60 2020-12-13    106       128     345.3
# 14     14        60 2020-12-14    104       132     379.3
# ...

# %%
for x in data.index:
  if data.loc[x, "Duration"] > 120:
    data.loc[x, "Duration"] = 120

# %%
for x in data.index:
  if data.loc[x, "Duration"] > 120:
    data.drop(x, inplace = True)

# %% [markdown]
# ## Clean duplicated

# %%
print(data.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
## Remove duplicates

data.drop_duplicates(inplace=True)
data
# Out:
#     Index  Duration       Date  Pulse  Maxpulse  Calories
# 0       0        60 2020-12-01    110       130     409.1
# 1       1        60 2020-12-02    117       145     479.0
# 2       2        60 2020-12-03    103       135     340.0
# 3       3        45 2020-12-04    109       175     282.4
# 4       4        45 2020-12-05    117       148     406.0
# 5       5        60 2020-12-06    102       127     300.0
# 6       6        60 2020-12-07    110       136     374.0
# 7       7        45 2020-12-08    104       134     253.3
# 8       8        30 2020-12-09    109       133     195.1
# 9       9        60 2020-12-10     98       124     269.0
# 10     10        60 2020-12-11    103       147     329.3
# 11     11        60 2020-12-12    100       120     250.7
# 12     12        60 2020-12-12    100       120     250.7
# 13     13        60 2020-12-13    106       128     345.3
# 14     14        60 2020-12-14    104       132     379.3
# ...

# %% [markdown]
# # Tài liệu tham khảo
#
# https://www.projectpro.io/data-science-in-python-tutorial/python-pandas-tutorial-for-beginners
#
# https://www.javatpoint.com/pandas-dropna
#
# https://www.tutorialspoint.com/python_pandas/python_pandas_visualization.htm
#
# https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/
